# %%
"""UAS KELOMPOK 5

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1VzWU1kFelN-qqgBrf00cZD-kYch5QW5T
"""

import random
import string
import time

start_time = time.time()

# Target string yang ingin dicapai
target = "PEMROGRAMAN LANJUTAN"

# Parameter algoritma genetika
population_size = 100
mutation_rate = 0.03
generations = 1000
parents_count = 3  # Jumlah orangtua yang digunakan dalam crossover
children_count = 2  # Jumlah anak yang dihasilkan dalam crossover

# Fungsi untuk menginisialisasi populasi
def initialize_population(size, length):
    return [''.join(random.choices(string.ascii_uppercase + " ", k=length)) for _ in range(size)]

# Fungsi untuk menghitung fitness individu
def calculate_fitness(individual):
    return sum(1 for i in range(len(individual)) if individual[i] == target[i])

# Fungsi untuk memilih individu berdasarkan fitness
def selection(population, num_parents):
    weights = [calculate_fitness(ind) for ind in population]
    total_fitness = sum(weights)
    probabilities = [w / total_fitness for w in weights]
    return random.choices(population, probabilities, k=num_parents)

# Fungsi untuk melakukan crossover antara tiga individu dan menghasilkan dua anak
def crossover(parents):
    length = len(parents[0])
    crossover_points = sorted(random.sample(range(1, length), 2))
    children = []
    for i in range(children_count):
        child = (parents[i % parents_count][:crossover_points[0]] +
                 parents[(i + 1) % parents_count][crossover_points[0]:crossover_points[1]] +
                 parents[(i + 2) % parents_count][crossover_points[1]:])
        children.append(child)
    return children

# Fungsi untuk melakukan mutasi pada individu
def mutate(individual, mutation_rate):
    return ''.join(random.choice(string.ascii_uppercase + " ") if random.random() < mutation_rate else char
                   for char in individual)

# Fungsi utama algoritma genetika
def genetic_algorithm():
    population = initialize_population(population_size, len(target))
    for generation in range(generations):
        population = sorted(population, key=calculate_fitness, reverse=True)
        if calculate_fitness(population[0]) == len(target):
            break
        next_population = population[:10]  # Elitisme: mempertahankan beberapa individu terbaik
        while len(next_population) < population_size:
            parents = selection(population, parents_count)
            children = crossover(parents)
            for child in children:
                child = mutate(child, mutation_rate)
                if len(next_population) < population_size:
                    next_population.append(child)
                else:
                    break
        population = next_population[:population_size]
        best_fitness = calculate_fitness(population[0])
        print(f"Generation {generation + 1}: Best fitness = {best_fitness}, Best individual = {population[0]}")
    return population[0]

# Menjalankan algoritma genetika
best_individual = genetic_algorithm()
print(f"\nBest individual: {best_individual}")

waktu = time.time() - start_time
print("\nWaktu komputasi:", waktu, "detik")
if waktu > 0:
    generations_per_second = (generations + 1) / waktu
else:
    generations_per_second = 0.0  # to avoid division by zero error
print("Kecepatan running: {:.2f} generasi/detik\n".format(generations_per_second))
# Out:
# Generation 1: Best fitness = 2, Best individual = VSRMGQVNTLYY OQJWLZN
# Generation 2: Best fitness = 3, Best individual = LXBKUSRVJIYTLYGNUWYU
# Generation 3: Best fitness = 4, Best individual = QMORHVIFZGSHLUNNMTSS
# Generation 4: Best fitness = 6, Best individual = XLMREBMZB V LUNNMTSS
# Generation 5: Best fitness = 8, Best individual = SEHRBSYAMGV LUNNMTSS
# Generation 6: Best fitness = 9, Best individual = PEARBSYAMLV LVNNMTYF
# Generation 7: Best fitness = 9, Best individual = PEARBSYAMLV LVNNMTYF
# Generation 8: Best fitness = 10, Best individual = EEARBVRAMLN LUNNMTKR
# Generation 9: Best fitness = 10, Best individual = EEARBVRAMLN LUNNMTKR
# Generation 10: Best fitness = 10, Best individual = EEARBVRAMLN LUNNMTKR
# Generation 11: Best fitness = 11, Best individual = OLMRBVRAMLN LUNGMTSN
# Generation 12: Best fitness = 11, Best individual = OLMRBVRAMLN LUNGMTSN
# Generation 13: Best fitness = 11, Best individual = OLMRBVRAMLN LUNGMTSN
# Generation 14: Best fitness = 12, Best individual = EEARPSRAMTN LVNJUTYU
# Generation 15: Best fitness = 12, Best individual = EEARPSRAMTN LVNJUTYU
# Generation 16: Best fitness = 13, Best individual = PEHREVRAMGN LVNJUTYU
# Generation 17: Best fitness = 13, Best individual = PEHREVRAMGN LVNJUTYU
# Generation 18: Best fitness = 13, Best individual = PEHREVRAMGN LVNJUTYU
# Generation 19: Best fitness = 13, Best individual = PEHREVRAMGN LVNJUTYU
# Generation 20: Best fitness = 13, Best individual = PEHREVRAMGN LVNJUTYU
# Generation 21: Best fitness = 14, Best individual = PEMRBVRAMGN LUNJUTTU
# Generation 22: Best fitness = 14, Best individual = PEMRBVRAMGN LUNJUTTU
# Generation 23: Best fitness = 14, Best individual = PEMRBVRAMGN LUNJUTTU
# Generation 24: Best fitness = 14, Best individual = PEMRBVRAMGN LUNJUTTU
# Generation 25: Best fitness = 14, Best individual = PEMRBVRAMGN LUNJUTTU
# Generation 26: Best fitness = 15, Best individual = PEPREVRAMGN LGNJUTAN
# Generation 27: Best fitness = 16, Best individual = PEHROSRAMTN LGNJUTAN
# Generation 28: Best fitness = 16, Best individual = PEHROSRAMTN LGNJUTAN
# Generation 29: Best fitness = 16, Best individual = PEHROSRAMTN LGNJUTAN
# Generation 30: Best fitness = 16, Best individual = PEHROSRAMTN LGNJUTAN
# Generation 31: Best fitness = 17, Best individual = PEMROSRAMXN LGNJUTAN
# Generation 32: Best fitness = 17, Best individual = PEMROSRAMXN LGNJUTAN
# Generation 33: Best fitness = 17, Best individual = PEMROSRAMXN LGNJUTAN
# Generation 34: Best fitness = 17, Best individual = PEMROSRAMXN LGNJUTAN
# Generation 35: Best fitness = 17, Best individual = PEMROSRAMXN LGNJUTAN
# Generation 36: Best fitness = 17, Best individual = PEMROSRAMXN LGNJUTAN
# Generation 37: Best fitness = 17, Best individual = PEMROSRAMXN LGNJUTAN
# Generation 38: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 39: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 40: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 41: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 42: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 43: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 44: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 45: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 46: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 47: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 48: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 49: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 50: Best fitness = 18, Best individual = PEMROSRAMAN LGNJUTAN
# Generation 51: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 52: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 53: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 54: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 55: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 56: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 57: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 58: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 59: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 60: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 61: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 62: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 63: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 64: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 65: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 66: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 67: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 68: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 69: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 70: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 71: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 72: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 73: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 74: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 75: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 76: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 77: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 78: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 79: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 80: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 81: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 82: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 83: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 84: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 85: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 86: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 87: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 88: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 89: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 90: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 91: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 92: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 93: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 94: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 95: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 96: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 97: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 98: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 99: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 100: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 101: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 102: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 103: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 104: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 105: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 106: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 107: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 108: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 109: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 110: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 111: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 112: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 113: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 114: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 115: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 116: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 117: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 118: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 119: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 120: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 121: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 122: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 123: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 124: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 125: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 126: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 127: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 128: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 129: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 130: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 131: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 132: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 133: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 134: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 135: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 136: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 137: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 138: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 139: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 140: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 141: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 142: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 143: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 144: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 145: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 146: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 147: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 148: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 149: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 150: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 151: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 152: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 153: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 154: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 155: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 156: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 157: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 158: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 159: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 160: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 161: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 162: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 163: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 164: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 165: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 166: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 167: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 168: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 169: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 170: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 171: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 172: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 173: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 174: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 175: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
# Generation 176: Best fitness = 19, Best individual = PEMROGRAMAN LGNJUTAN
#
# Best individual: PEMROGRAMAN LANJUTAN
#
# Waktu komputasi: 7.921984434127808 detik
# Kecepatan running: 126.36 generasi/detik
